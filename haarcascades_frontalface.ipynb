# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicovirdiano/haarcascades-frontalface/blob/main/haarcascades_frontalface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9d234019-3cc3-43ce-b299-59d10172e3de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d234019-3cc3-43ce-b299-59d10172e3de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2

haar_fila =  '/content/haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(haar_fila)
webcam = cv2.VideoCapture(0)
print (haar_fila)

while True:
  (_,im) = webcam.read()
  gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray)
  for (x, y, w, h) in faces:
      cv2.rectangle(im, (x,y), (x+w, y+h), (255, 0, 0,), 2)

  cv2.imshow("OpenCV", im)   

  key = cv2.waitKey(10)
  if key == 27:
    break

# %%
import cv2
captura = cv2.VideoCapture(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1b29d15c8030> in <module>
#       2 captura = cv2.VideoCapture(0)
#       3
# ----> 4 while (captura.isOpened):
#       5   ret, video = captura.read()
#       6   if(ret):
#
# KeyboardInterrupt:
